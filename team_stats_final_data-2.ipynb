# 151  Los Angeles Clippers  2018            82  19830.0         1853    9442
# 189  Los Angeles Clippers  2019            72  17380.0         1498    8377
# 231  Los Angeles Clippers  2020            72  17280.0         1164    8209
# 265  Los Angeles Clippers  2021            82  19780.0         1273    8890
#
#      Three Pointers  Second Chance Points  Counter Attack Points  Blocks  \
# 1               693                  1101                   1488     397
# ...

# %%
df_wins = pd.read_csv("/content/team_wins_by_year.csv")
df_wins.head()
# Out:
#    Unnamed: 0         Team Name  Wins  Loss  Year
# 0           0        Utah  Jazz    25    57  2013
# 1           1  Detroit  Pistons    29    53  2013
# 2           2    Atlanta  Hawks    38    44  2013
# 3           3    Orlando  Magic    23    59  2013
# 4           4   Indiana  Pacers    56    26  2013

# %%
df_wins = df_wins.drop(['Unnamed: 0'],axis=1)

# %%
df_wins.rename(columns = {'Team Name':'Team Name1'}, inplace = True)

# %%
df_wins.head()
# Out:
#          Team Name1  Wins  Loss  Year
# 0        Utah  Jazz    25    57  2013
# 1  Detroit  Pistons    29    53  2013
# 2    Atlanta  Hawks    38    44  2013
# 3    Orlando  Magic    23    59  2013
# 4   Indiana  Pacers    56    26  2013

# %%
df_wins = df_wins.sort_values(['Year','Team Name1'],ascending = [True,True])

# %%
df = df.sort_values(['Year','Team Name'],ascending = [True,True])

# %%
df.reset_index(inplace=True)
df_wins.reset_index(inplace=True)

# %%
df = df.drop(['index'],axis=1)
df_wins = df_wins.drop(['index'],axis=1)

# %%
df.head(10)
# Out:
#                Team Name  Year  Games Played  Minutes  Free Throws  Points  \
# 0          Atlanta Hawks  2013            82  21055.0         1392    8282
# 1         Boston Celtics  2013            82  20930.0         1325    7892
# 2          Brooklyn Nets  2013            82  21105.0         1508    8079
# 3      Charlotte Hornets  2013            82  22570.0         1474    7942
# 4          Chicago Bulls  2013            82  21130.0         1486    7680
# 5    Cleveland Cavaliers  2013            82  21610.0         1398    8054
# 6       Dallas Mavericks  2013            82  22255.0         1378    8597
# 7         Denver Nuggets  2013            82  21195.0         1563    8559
# 8        Detroit Pistons  2013            82  21750.0         1415    8286
# 9  Golden State Warriors  2013            82  20550.0         1303    8549
#
#    Three Pointers  Second Chance Points  Counter Attack Points  Blocks  \
# ...

# %%
df_wins.head(10)
# Out:
#                Team Name1  Wins  Loss  Year
# 0          Atlanta  Hawks    38    44  2013
# 1         Boston  Celtics    25    57  2013
# 2          Brooklyn  Nets    44    38  2013
# 3      Charlotte  Hornets    43    39  2013
# 4          Chicago  Bulls    48    34  2013
# 5    Cleveland  Cavaliers    33    49  2013
# 6       Dallas  Mavericks    49    33  2013
# 7         Denver  Nuggets    36    46  2013
# 8        Detroit  Pistons    29    53  2013
# 9  Golden State  Warriors    51    31  2013

# %%
result = pd.concat([df, df_wins], axis=1, join='inner')
display(result)
# Out:
#                   Team Name  Year  Games Played  Minutes  Free Throws  Points  \
# 0             Atlanta Hawks  2013            82  21055.0         1392    8282
# 1            Boston Celtics  2013            82  20930.0         1325    7892
# 2             Brooklyn Nets  2013            82  21105.0         1508    8079
# 3         Charlotte Hornets  2013            82  22570.0         1474    7942
# 4             Chicago Bulls  2013            82  21130.0         1486    7680
# 5       Cleveland Cavaliers  2013            82  21610.0         1398    8054
# 6          Dallas Mavericks  2013            82  22255.0         1378    8597
# 7            Denver Nuggets  2013            82  21195.0         1563    8559
# 8           Detroit Pistons  2013            82  21750.0         1415    8286
# 9     Golden State Warriors  2013            82  20550.0         1303    8549
# 10          Houston Rockets  2013            82  21270.0         1814    8829
# ...

# %%
result = result.iloc[:,:-1]

# %%
result = result.drop(['Team Name1'], axis=1)

# %%
winPercentage= []

for i in range(len(result)):
    winPercent = (result.loc[i,"Wins"]/result.loc[i,"Games Played"])*100
    winPercentage.append(winPercent)
    
result['Win Percentage'] = winPercentage

# %%
lossPercentage= []

for i in range(len(result)):
    lossPercent = (100 - result.loc[i,"Win Percentage"])
    lossPercentage.append(lossPercent)
    
result['Loss Percentage'] = lossPercentage

# %%
result = result.round({"Loss Percentage":2, "Win Percentage":2})

# %%
result = result.reindex(columns=['Team Name', 'Year', 'Games Played',
                                 'Minutes','Wins','Loss',	'Win Percentage',	'Loss Percentage','Points', 
                                 'Three Pointers', 'Two Pointers',
                                 'Second Chance Points','Counter Attack Points', 'Free Throws',	'Blocks',	'Blocked Attempts',
                                 'Personal Fouls','Flagrant Fouls', 'Team Technical Fouls',
                                 'Team Fouls','Total Fouls','Total Rebounds','Rebounds', 'Assists',	'Turnovers',	
                                 'Assists Turnover Ratio','Steals'])

# %%
result.head(10)
# Out:
#                Team Name  Year  Games Played  Minutes  Wins  Loss  \
# 0          Atlanta Hawks  2013            82  21055.0    38    44
# 1         Boston Celtics  2013            82  20930.0    25    57
# 2          Brooklyn Nets  2013            82  21105.0    44    38
# 3      Charlotte Hornets  2013            82  22570.0    43    39
# 4          Chicago Bulls  2013            82  21130.0    48    34
# 5    Cleveland Cavaliers  2013            82  21610.0    33    49
# 6       Dallas Mavericks  2013            82  22255.0    49    33
# 7         Denver Nuggets  2013            82  21195.0    36    46
# 8        Detroit Pistons  2013            82  21750.0    29    53
# 9  Golden State Warriors  2013            82  20550.0    51    31
#
#    Win Percentage  Loss Percentage  Points  Three Pointers  Two Pointers  \
# 0           46.34            53.66    8282             768          2293
# 1           30.49            69.51    7892             575          2421
# ...

# %%
result.to_csv("Yearly_NBA_Team_Stats_Data1.csv")
