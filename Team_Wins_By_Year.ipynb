# %%
import requests
import pandas as pd

# %%
key = "ef857kbt3e44tvk6vsxwgxzx"

# %%
overall = requests.get("https://api.sportradar.com/nba/trial/v7/en/seasons/2021/REG/standings.json?api_key="+key)
overall = overall.json()
overall
# Out:
# {'league': {'id': '4353138d-4c22-4396-95d8-5f587d2df25c',
#   'name': 'NBA',
#   'alias': 'NBA'},
#  'season': {'id': '16d6292c-25c6-4487-aa90-912c1e09170b',
#   'year': 2021,
#   'type': 'REG'},
#  'conferences': [{'id': '7fe7e212-de01-4f8f-a31d-b9f0a95731e3',
#    'name': 'WESTERN CONFERENCE',
#    'alias': 'WESTERN',
#    'divisions': [{'id': '1d29f94c-9587-494b-a232-feb20a40eb4c',
#      'name': 'Southwest',
#      'alias': 'SOUTHWEST',
#      'teams': [{'id': '583eca88-fb46-11e1-82cb-f4ce4684ea4c',
#        'name': 'Grizzlies',
#        'market': 'Memphis',
#        'wins': 56,
#        'losses': 26,
#        'win_pct': 0.683,
#        'points_for': 115.61,
#        'points_against': 109.93,
#        'point_diff': 5.68,
#        'sr_id': 'sr:team:3415',
#        'reference': '1610612763',
#        'games_behind': {'league': 8.0, 'conference': 8.0, 'division': 0.0},
#        'streak': {'kind': 'loss', 'length': 1},
#        'calc_rank': {'div_rank': 1, 'conf_rank': 2},
# ...

# %%
overall2013 = overall_data("2013",key)
overall2013['Year'] = 2013
overall2013
# Out:
#                             Wins  Loss  Year
#    Team Name
# 1  Los Angeles  Clippers      57    25  2013
# 2  Golden State  Warriors     51    31  2013
# 3  Phoenix  Suns              48    34  2013
# 4  Sacramento  Kings          28    54  2013
# 5  Los Angeles  Lakers        27    55  2013
# 6  San Antonio  Spurs         62    20  2013
# 7  Houston  Rockets           54    28  2013
# 8  Memphis  Grizzlies         50    32  2013
# 9  Dallas  Mavericks          49    33  2013
# 10 New Orleans  Pelicans      34    48  2013
# 11 Oklahoma City  Thunder     59    23  2013
# 12 Portland  Trail Blazers    54    28  2013
# 13 Minnesota  Timberwolves    40    42  2013
# 14 Denver  Nuggets            36    46  2013
# 15 Utah  Jazz                 25    57  2013
# 16 Miami  Heat                54    28  2013
# 17 Washington  Wizards        44    38  2013
# 18 Charlotte  Hornets         43    39  2013
# 19 Atlanta  Hawks             38    44  2013
# ...

# %%
overall2014 = overall_data("2014",key)
overall2014['Year'] = 2014
overall2014
# Out:
#                             Wins  Loss  Year
#    Team Name
# 1  Atlanta  Hawks             60    22  2014
# 2  Washington  Wizards        46    36  2014
# 3  Miami  Heat                37    45  2014
# 4  Charlotte  Hornets         33    49  2014
# 5  Orlando  Magic             25    57  2014
# 6  Toronto  Raptors           49    33  2014
# 7  Boston  Celtics            40    42  2014
# 8  Brooklyn  Nets             38    44  2014
# 9  Philadelphia  76ers        18    64  2014
# 10 New York  Knicks           17    65  2014
# 11 Cleveland  Cavaliers       53    29  2014
# 12 Chicago  Bulls             50    32  2014
# 13 Milwaukee  Bucks           41    41  2014
# 14 Indiana  Pacers            38    44  2014
# 15 Detroit  Pistons           32    50  2014
# 16 Houston  Rockets           56    26  2014
# 17 San Antonio  Spurs         55    27  2014
# 18 Memphis  Grizzlies         55    27  2014
# 19 Dallas  Mavericks          50    32  2014
# 14 Portland  Trail Blazers    27    55  2021
# 15 Oklahoma City  Thunder     24    58  2021
# 16 Miami  Heat                53    29  2021
# 17 Atlanta  Hawks             43    39  2021
# 18 Charlotte  Hornets         43    39  2021
# 19 Washington  Wizards        35    47  2021
# ...

# %%
overall2013.to_csv('NBA_Team_Wins_2013.csv')

# %%
overall2014.to_csv('NBA_Team_Wins_2014.csv')

# %%
overall2015.to_csv('NBA_Team_Wins_2015.csv')

# %%
overall2016.to_csv('NBA_Team_Wins_2016.csv')

# %%
overall2017.to_csv('NBA_Team_Wins_2017.csv')

# %%
overall2018.to_csv('NBA_Team_Wins_2018.csv')

# %%
overall2019.to_csv('NBA_Team_Wins_2019.csv')

# %%
overall2020.to_csv('NBA_Team_Wins_2020.csv')

# %%
overall2021.to_csv('NBA_Team_Wins_2021.csv')

# %%
import os
import pandas as pd
import glob
#list all csv files only
csv_files = glob.glob('*.{}'.format('csv'))
csv_files
# Out:
# ['NBA_Team_Wins_2018.csv',
#  'NBA_Team_Wins_2014.csv',
#  'NBA_Team_Wins_2021.csv',
#  'NBA_Team_Wins_2020.csv',
#  'NBA_Team_Wins_2013.csv',
#  'NBA_Team_Wins_2019.csv',
#  'NBA_Team_Wins_2016.csv',
#  'NBA_Team_Wins_2015.csv',
#  'NBA_Team_Wins_2017.csv']

# %%
df_append = pd.DataFrame()
#append all files together
for file in csv_files:
            df_temp = pd.read_csv(file)
            df_append = df_append.append(df_temp, ignore_index=True)
df_append
# Out:
#      Unnamed: 0                Team Name  Wins  Loss  Year
# 0             1   Golden State  Warriors    57    25  2018
# 1             2             LA  Clippers    48    34  2018
# 2             3        Sacramento  Kings    39    43  2018
# 3             4      Los Angeles  Lakers    37    45  2018
# 4             5            Phoenix  Suns    19    63  2018
# ..          ...                      ...   ...   ...   ...
# 265          26  Portland  Trail Blazers    49    33  2017
# 266          27               Utah  Jazz    48    34  2017
# 267          28   Oklahoma City  Thunder    48    34  2017
# 268          29  Minnesota  Timberwolves    47    35  2017
# 269          30          Denver  Nuggets    46    36  2017
#
# [270 rows x 5 columns]

# %%
df_append = df_append.drop(['Unnamed: 0'],axis=1)

# %%
df_append
# Out:
#                    Team Name  Wins  Loss  Year
# 0     Golden State  Warriors    57    25  2018
# 1               LA  Clippers    48    34  2018
# 2          Sacramento  Kings    39    43  2018
# 3        Los Angeles  Lakers    37    45  2018
# 4              Phoenix  Suns    19    63  2018
# ..                       ...   ...   ...   ...
# 265  Portland  Trail Blazers    49    33  2017
# 266               Utah  Jazz    48    34  2017
# 267   Oklahoma City  Thunder    48    34  2017
# 268  Minnesota  Timberwolves    47    35  2017
# 269          Denver  Nuggets    46    36  2017
#
# [270 rows x 4 columns]

# %%
df_append = df_append.sort_values(by=['Year'],ignore_index=True)
df_append
# Out:
#                    Team Name  Wins  Loss  Year
# 0                 Utah  Jazz    25    57  2013
# 1           New York  Knicks    37    45  2013
# 2             Brooklyn  Nets    44    38  2013
# 3            Denver  Nuggets    36    46  2013
# 4           Toronto  Raptors    48    34  2013
# ..                       ...   ...   ...   ...
# 265       Memphis  Grizzlies    56    26  2021
# 266     Cleveland  Cavaliers    44    38  2021
# 267  Portland  Trail Blazers    27    55  2021
# 268              Miami  Heat    53    29  2021
# 269         Detroit  Pistons    23    59  2021
#
# [270 rows x 4 columns]

# %%
df_append.to_csv("team_wins_by_year.csv")
